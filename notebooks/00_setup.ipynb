# %% [markdown]
# # Day 1 — 环境检查与准备
#
# 目前使用笔记本，AMD处理器且无GPU，后续有必要再使用实验室服务器
#
# 🎯 目标：
# - 验证 Python / Conda / PyTorch / 常用库是否安装成功
# - 运行简单示例，确认环境无误
# - 输出环境信息，方便复现
#
# ---

# %%
# ============================
# 1. Python 基本信息
# ============================
import sys
print("✅ Python version:", sys.version)
# Out:
# ✅ Python version: 3.10.18 | packaged by Anaconda, Inc. | (main, Jun  5 2025, 13:08:55) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# ---
# ## 2. PyTorch 检查
# 这里我们检查 PyTorch 是否能正常导入，并确认 CUDA (GPU) 是否可用。
# ---

# %%
import torch

print("✅ Torch version:", torch.__version__)
print("✅ CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("CUDA device count:", torch.cuda.device_count())
    print("Current device:", torch.cuda.current_device())
    print("Device name:", torch.cuda.get_device_name(torch.cuda.current_device()))
else:
    print("⚠️ CUDA device not available, running on CPU.")
# Out:
# ✅ Torch version: 2.8.0+cpu
# ✅ CUDA available: False
# ⚠️ CUDA device not available, running on CPU.

# %% [markdown]
# ---
# ## 3. 常用库检查
# 我们还需要验证数据科学常用库是否安装成功：
# - numpy
# - pandas
# - scikit-learn
# - matplotlib
# ---

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib

print("✅ Numpy:", np.__version__)
print("✅ Pandas:", pd.__version__)
print("✅ Scikit-learn:", sklearn.__version__)
print("✅ Matplotlib:", matplotlib.__version__)
# Out:
# ✅ Numpy: 2.2.6
# ✅ Pandas: 2.3.2
# ✅ Scikit-learn: 1.7.1
# ✅ Matplotlib: 3.10.5

# %% [markdown]
# ---
# ## 4. Numpy 测试 — 矩阵乘法
# ---

# %%
A = np.random.rand(3,3)
B = np.random.rand(3,3)

print("Matrix A:\n", A)
print("Matrix B:\n", B)
print("A @ B =\n", A @ B)
# Out:
# Matrix A:
#  [[0.43801403 0.89684995 0.70633679]
#  [0.27106867 0.48884848 0.96908969]
#  [0.57761051 0.19584528 0.90787564]]
# Matrix B:
#  [[0.32249672 0.25280236 0.25275532]
#  [0.87900758 0.7875049  0.61359771]
#  [0.1780424  0.26417785 0.32276849]]
# A @ B =
#  [[1.05535389 1.00360325 0.88899871]
#  [0.68965933 0.70950941 0.68126197]
#  [0.52006733 0.54009105 0.55919799]]

# %% [markdown]
# ---
# ## 5. Pandas 测试 — DataFrame
# ---

# %%
df = pd.DataFrame({
    "user_id": [1,2,3],
    "movie_id": [101,102,103],
    "rating": [5,4,3]
})
print("Sample DataFrame:\n", df)
# Out:
# Sample DataFrame:
#     user_id  movie_id  rating
# 0        1       101       5
# 1        2       102       4
# 2        3       103       3

# %% [markdown]
# ---
# ## 6. Matplotlib 测试 — 绘图
# ---

# %%
import matplotlib.pyplot as plt

x = np.linspace(-3, 3, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Test Plot: y = sin(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## 7. 总结
# 如果所有步骤都能顺利执行，说明 Day 1 环境已经准备就绪 ✅
# ---
